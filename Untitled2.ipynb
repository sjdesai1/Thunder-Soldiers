# %%
from config import api_key
from yelpapi import YelpAPI
import requests
import pandas as pd
import numpy as np
from pprint import pprint

# %%
cities = ["Irvine", "Santa Ana","Costa Mesa","Lake Forest","Newport Beach","Tustin","Gardon Grove","Fullerton","Mission Viejo","Laguna Beach"]
url = "https://api.yelp.com/v3/businesses/search"
headers = {'Authorization': 'Bearer %s' %api_key}
business_id = []
for c in cities:
    params = {'term':"restaurant" ,"location": c,"limit": 50,"radius": 5000}
    responses = requests.get(url,headers = headers, params = params).json()
    for response in responses["businesses"]:
        business_id.append(response["id"])

# %%
yelp_api = YelpAPI(api_key)
responses = []
for b in business_id:
    responses.append(yelp_api.business_query(id = b))

# %%
dates_time = []
ratings = []
for r in responses:
    try:
        dates_time.append(r["hours"][0]["open"])
        ratings.append(r["rating"])
    except KeyError: #some stores didn't list out operation hours
        continue

# %%
pprint(dates_time)
# Out:
# [[{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1045'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1045'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1045'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1045'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1045'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1045'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1045'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1200'}],
#  [{'day': 0, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '0000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 1, 'end': '1930', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '1930', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '1930', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '1930', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '1930', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '1930', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2300', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 5, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '0900'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 5, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 6, 'end': '0000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1600', 'is_overnight': False, 'start': '0800'},
#   {'day': 1, 'end': '1600', 'is_overnight': False, 'start': '0800'},
#   {'day': 2, 'end': '1600', 'is_overnight': False, 'start': '0800'},
#   {'day': 3, 'end': '1600', 'is_overnight': False, 'start': '0800'},
#   {'day': 4, 'end': '1600', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '1400', 'is_overnight': False, 'start': '0630'},
#   {'day': 1, 'end': '1400', 'is_overnight': False, 'start': '0630'},
#   {'day': 2, 'end': '1400', 'is_overnight': False, 'start': '0630'},
#   {'day': 3, 'end': '1400', 'is_overnight': False, 'start': '0630'},
#   {'day': 4, 'end': '1400', 'is_overnight': False, 'start': '0630'},
#   {'day': 5, 'end': '1400', 'is_overnight': False, 'start': '0630'},
#   {'day': 6, 'end': '1400', 'is_overnight': False, 'start': '0630'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1430', 'is_overnight': False, 'start': '1100'},
#   {'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1430', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1430', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1430', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '1430', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '1430', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1030'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2230', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2230', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 1, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 2, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 3, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 4, 'end': '0300', 'is_overnight': True, 'start': '1100'},
#   {'day': 5, 'end': '0300', 'is_overnight': True, 'start': '0800'},
#   {'day': 6, 'end': '0200', 'is_overnight': True, 'start': '0800'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2030', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2300', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 1, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#   {'day': 1, 'end': '0000', 'is_overnight': False, 'start': '1830'},
#   {'day': 2, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#   {'day': 2, 'end': '0000', 'is_overnight': False, 'start': '1830'},
#   {'day': 3, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#   {'day': 3, 'end': '0000', 'is_overnight': False, 'start': '1830'},
#   {'day': 4, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1830'},
#   {'day': 5, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1830'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 1, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 2, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 3, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 4, 'end': '1700', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1030'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1030'}],
#  [{'day': 0, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1630'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0630'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0630'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0630'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0630'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '0630'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '0730'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0730'}],
#  [{'day': 0, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1000'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2030', 'is_overnight': False, 'start': '1000'},
#   {'day': 1, 'end': '2030', 'is_overnight': False, 'start': '1000'},
#   {'day': 2, 'end': '2030', 'is_overnight': False, 'start': '1000'},
#   {'day': 3, 'end': '2030', 'is_overnight': False, 'start': '1000'},
#   {'day': 4, 'end': '2030', 'is_overnight': False, 'start': '1000'},
#   {'day': 5, 'end': '2030', 'is_overnight': False, 'start': '1000'},
#   {'day': 6, 'end': '2030', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 0, 'end': '2230', 'is_overnight': False, 'start': '1630'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2230', 'is_overnight': False, 'start': '1630'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2230', 'is_overnight': False, 'start': '1630'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2230', 'is_overnight': False, 'start': '1630'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1630'},
#   {'day': 5, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1630'},
#   {'day': 6, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 6, 'end': '2230', 'is_overnight': False, 'start': '1630'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1000'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1000'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1000'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1000'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1000'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1000'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1600'}],
#  [{'day': 0, 'end': '2000', 'is_overnight': False, 'start': '0730'},
#   {'day': 1, 'end': '2000', 'is_overnight': False, 'start': '0730'},
#   {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '0730'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '0730'},
#   {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '0730'},
#   {'day': 5, 'end': '1600', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 1, 'end': '1800', 'is_overnight': False, 'start': '1200'},
#   {'day': 2, 'end': '1800', 'is_overnight': False, 'start': '1200'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1200'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1200'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1200'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '1200'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '0130', 'is_overnight': True, 'start': '1130'},
#   {'day': 5, 'end': '0130', 'is_overnight': True, 'start': '1130'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 1, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 2, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 3, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 4, 'end': '1700', 'is_overnight': False, 'start': '1000'},
#   {'day': 5, 'end': '1700', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '0700'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 1, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '1500', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '0700'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0700'}],
#  [{'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '1500', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '0200', 'is_overnight': True, 'start': '1030'},
#   {'day': 1, 'end': '0200', 'is_overnight': True, 'start': '1030'},
#   {'day': 2, 'end': '0200', 'is_overnight': True, 'start': '1030'},
#   {'day': 3, 'end': '0200', 'is_overnight': True, 'start': '1030'},
#   {'day': 4, 'end': '0200', 'is_overnight': True, 'start': '1030'},
#   {'day': 5, 'end': '0200', 'is_overnight': True, 'start': '1030'},
#   {'day': 6, 'end': '0200', 'is_overnight': True, 'start': '1030'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '0900'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '1600', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '1600', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '1600', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '1600', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '1600', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '1600', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '0100', 'is_overnight': True, 'start': '1100'},
#   {'day': 4, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 5, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 6, 'end': '0000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 2, 'end': '0000', 'is_overnight': True, 'start': '0000'},
#   {'day': 3, 'end': '0000', 'is_overnight': True, 'start': '0000'},
#   {'day': 4, 'end': '0000', 'is_overnight': True, 'start': '0000'},
#   {'day': 5, 'end': '0930', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 0, 'end': '2030', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2030', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2030', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2030', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2030', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2030', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2030', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1600'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1600'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '1600', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '0600'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '0600'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '0600'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '0600'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '0600'},
#   {'day': 5, 'end': '1500', 'is_overnight': False, 'start': '0600'},
#   {'day': 6, 'end': '1500', 'is_overnight': False, 'start': '0600'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1200'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '1800', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1000'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1000'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1800', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '1800', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '1800', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '1800', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '1800', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '1800', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '1800', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1730'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1730'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1730'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1730'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1730'},
#   {'day': 5, 'end': '1500', 'is_overnight': False, 'start': '1030'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2000', 'is_overnight': False, 'start': '0900'},
#   {'day': 1, 'end': '2000', 'is_overnight': False, 'start': '0900'},
#   {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '0900'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '0900'},
#   {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '0900'},
#   {'day': 5, 'end': '1700', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1030'}],
#  [{'day': 0, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1730'},
#   {'day': 1, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1730'},
#   {'day': 2, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1730'},
#   {'day': 3, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1730'},
#   {'day': 4, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2130', 'is_overnight': False, 'start': '1730'},
#   {'day': 5, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2130', 'is_overnight': False, 'start': '1730'},
#   {'day': 6, 'end': '1500', 'is_overnight': False, 'start': '1130'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1730'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1030'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1030'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1030'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1030'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '1600', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '1600', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '1500', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1400', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1400', 'is_overnight': False, 'start': '1130'},
# ...
#   {'day': 1, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '0100', 'is_overnight': True, 'start': '1700'},
#   {'day': 5, 'end': '0100', 'is_overnight': True, 'start': '1700'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1130'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1130'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1000'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2300', 'is_overnight': False, 'start': '0800'},
#   {'day': 1, 'end': '2300', 'is_overnight': False, 'start': '0800'},
#   {'day': 2, 'end': '2300', 'is_overnight': False, 'start': '0800'},
#   {'day': 3, 'end': '2300', 'is_overnight': False, 'start': '0800'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '0800'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '2300', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2300', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '1700', 'is_overnight': False, 'start': '0900'},
#   {'day': 1, 'end': '1700', 'is_overnight': False, 'start': '0900'},
#   {'day': 2, 'end': '1700', 'is_overnight': False, 'start': '0900'},
#   {'day': 3, 'end': '1700', 'is_overnight': False, 'start': '0900'},
#   {'day': 4, 'end': '1700', 'is_overnight': False, 'start': '0900'},
#   {'day': 5, 'end': '1700', 'is_overnight': False, 'start': '0900'},
#   {'day': 6, 'end': '1700', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 2, 'end': '2230', 'is_overnight': False, 'start': '1430'},
#   {'day': 3, 'end': '2230', 'is_overnight': False, 'start': '1430'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1430'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1200'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '0600'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '0600'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '0600'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '0600'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '0600'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '0600'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '0600'}],
#  [{'day': 0, 'end': '2230', 'is_overnight': False, 'start': '1600'},
#   {'day': 1, 'end': '2230', 'is_overnight': False, 'start': '1600'},
#   {'day': 2, 'end': '2230', 'is_overnight': False, 'start': '1600'},
#   {'day': 3, 'end': '2230', 'is_overnight': False, 'start': '1600'},
#   {'day': 4, 'end': '0200', 'is_overnight': True, 'start': '1600'},
#   {'day': 5, 'end': '0200', 'is_overnight': True, 'start': '1130'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1130'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1900', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '1900', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '1900', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '1900', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '0100', 'is_overnight': True, 'start': '1100'},
#   {'day': 5, 'end': '0100', 'is_overnight': True, 'start': '0900'},
#   {'day': 6, 'end': '2300', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 0, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 6, 'end': '1700', 'is_overnight': False, 'start': '0700'}],
#  [{'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '1900', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '1900', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '1900', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '1900', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '1900', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '1900', 'is_overnight': False, 'start': '0700'},
#   {'day': 6, 'end': '1900', 'is_overnight': False, 'start': '0700'}],
#  [{'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1000'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1630'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1630'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1630'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1630'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1630'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '1630'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1630'}],
#  [{'day': 0, 'end': '2230', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2230', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2230', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2230', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2300', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2300', 'is_overnight': False, 'start': '0900'},
#   {'day': 6, 'end': '2230', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 0, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '0000', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 5, 'end': '0200', 'is_overnight': True, 'start': '1100'},
#   {'day': 6, 'end': '0000', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '1100'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1100'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '1100'}],
#  [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '0800'},
#   {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '0800'}],
#  [{'day': 0, 'end': '2000', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '2000', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '0700'},
#   {'day': 6, 'end': '2000', 'is_overnight': False, 'start': '0700'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '0700'},
#   {'day': 6, 'end': '2100', 'is_overnight': False, 'start': '0700'}],
#  [{'day': 0, 'end': '1530', 'is_overnight': False, 'start': '1200'},
#   {'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 1, 'end': '1530', 'is_overnight': False, 'start': '1200'},
#   {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 2, 'end': '1530', 'is_overnight': False, 'start': '1200'},
#   {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 3, 'end': '1530', 'is_overnight': False, 'start': '1200'},
#   {'day': 3, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#   {'day': 4, 'end': '1530', 'is_overnight': False, 'start': '1200'},
#   {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 5, 'end': '1600', 'is_overnight': False, 'start': '1200'},
#   {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1700'},
#   {'day': 6, 'end': '1600', 'is_overnight': False, 'start': '1200'},
#   {'day': 6, 'end': '2130', 'is_overnight': False, 'start': '1700'}],
#  [{'day': 0, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 1, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 2, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 3, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 4, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 5, 'end': '2100', 'is_overnight': False, 'start': '0900'},
#   {'day': 6, 'end': '2000', 'is_overnight': False, 'start': '0900'}],
#  [{'day': 0, 'end': '1600', 'is_overnight': False, 'start': '0630'},
#   {'day': 1, 'end': '1600', 'is_overnight': False, 'start': '0630'},
#   {'day': 2, 'end': '1600', 'is_overnight': False, 'start': '0630'},
#   {'day': 3, 'end': '1600', 'is_overnight': False, 'start': '0630'},
#   {'day': 4, 'end': '1600', 'is_overnight': False, 'start': '0630'},
#   {'day': 5, 'end': '1700', 'is_overnight': False, 'start': '0700'},
#   {'day': 6, 'end': '1700', 'is_overnight': False, 'start': '0700'}]]

# %%
for date_time in dates_time:
    total = 0
    for x in range(len(date_time)):
        if int(date_time[x]["end"]) == 0:
            total += 2400-int(date_time[x]["start"])
        elif int(date_time[x]["end"]) < 600:
#             print(date_time[x]["day"])
            total += int(date_time[x]["end"])+2400 - int(date_time[x]["start"])
        else:
            total += int(date_time[x]["end"])-int(date_time[x]["start"])
            if total < 0:
                print(total)
                print(date_time[x]["end"])
    avg = round(total / (len(date_time) * 100))
    
    print(avg)
# Out:
# 12
# 10
# 5
# 12
# 8
# 10
# 12
# 10
# 13
# 11
# 10
# 14
# 10
# 10
# 10
# 8
# 4
# 8
# 11
# 10
# 4
# 10
# 12
# 10
# 5
# 16
# 10
# 10
# 5
# 10
# 9
# 5
# 12
# 12
# 4
# 10
# 7
# 11
# 13
# 10
# 4
# 14
# 9
# 4
# 11
# 11
# 10
# 5
# 11
# 12
# 6
# 6
# 8
# 12
# 7
# 10
# 10
# 11
# 15
# 11
# 9
# 9
# 15
# 5
# 16
# 13
# 5
# 14
# 10
# 10
# 7
# 16
# 10
# 7
# 9
# 11
# 5
# 10
# 10
# 10
# 11
# 7
# 4
# 10
# 10
# 11
# 4
# 12
# 11
# 13
# 9
# 11
# 10
# 4
# 5
# 5
# 14
# 9
# 5
# 10
# 14
# 13
# 10
# 9
# 6
# 14
# 11
# 8
# 5
# 13
# 11
# 12
# 12
# 4
# 13
# 9
# 15
# 9
# 8
# 11
# 10
# 6
# 9
# 11
# 4
# 10
# 12
# 10
# 10
# 15
# 4
# 10
# 17
# 11
# 10
# 5
# 10
# 10
# 12
# 10
# 10
# 11
# 4
# 16
# 5
# 11
# 4
# 12
# 4
# 4
# 4
# 9
# 5
# 4
# 9
# 11
# 9
# 8
# 5
# 13
# 11
# 10
# 10
# 11
# 6
# 4
# 10
# 11
# 4
# 5
# 8
# 4
# 9
# 12
# 4
# 10
# 4
# 4
# 11
# 10
# 12
# 8
# 12
# 10
# 10
# 9
# 8
# 11
# 10
# 10
# 12
# 11
# 10
# 12
# 4
# 10
# 9
# 10
# 5
# 10
# 11
# 11
# 11
# 4
# 11
# 6
# 5
# 10
# 10
# 10
# 10
# 10
# 5
# 10
# 10
# 14
# 12
# 5
# 15
# 5
# 12
# 11
# 10
# 4
# 5
# 13
# 10
# 10
# 3
# 10
# 6
# 11
# 13
# 14
# 13
# 13
# 9
# 15
# 8
# 10
# 11
# 4
# 16
# 13
# 18
# 5
# 9
# 11
# 13
# 11
# 8
# 8
# 13
# 4
# 4
# 11
# 10
# 4
# 10
# 10
# 6
# 10
# 11
# 4
# 8
# 13
# 4
# 11
# 10
# 14
# 4
# 10
# 10
# 3
# 10
# 9
# 11
# 8
# 11
# 10
# 6
# 11
# 6
# 11
# 10
# 10
# 10
# 10
# 4
# 11
# 12
# 11
# 7
# 5
# 13
# 14
# 10
# 9
# 11
# 11
# 10
# 11
# 12
# 11
# 13
# 8
# 11
# 5
# 5
# 13
# 6
# 4
# 11
# 12
# 10
# 11
# 12
# 12
# 12
# 7
# 14
# 9
# 11
# 11
# 6
# 11
# 12
# 13
# 11
# 11
# 10
# 10
# 12
# 8
# 12
# 8
# 14
# 11
# 10
# 8
# 15
# 12
# 8
# 16
# 12
# 13
# 7
# 12
# 11
# 10
# 11
# 6
# 12
# 5
# 11
# 12
# 10
# 10
# 11
# 10
# 10
# 11
# 7
# 14
# 4
# 8
# 11
# 5
# 11
# 10
# 7
# 14
# 11
# 11
# 7
# 11
# 10
# 10
# 11
# 10
# 7
# 9
# 11
# 10
# 14
# 11
# 5
# 9
# 10
# 13
# 16
# 10
# 18
# 11
# 9
# 10
# 9
# 8
# 5
# 10
# 14
# 5
# 5
# 12
# 5
# 12
# 10
# 14
# 8
# 12
# 10
# 12
# 15
# 11
# 14
# 4
# 14
# 9
# 9
# 10
# 8
# 11
# 14
# 9
# 9
# 9
# 9
# 16
# 5
# 9
# 11
# 10
# 9
# 10
# 12
# 4
# 12
# 9
# 4
# 11
# 14
# 5
# 10
# 12
# 10
# 5
# 11
# 12
# 8
# 6
# 11
# 11
# 10
# 15
# 12
# 14
# 7
# 4
# 13
# 9
# 6
# 11
# 11
# 15
# 5
# 8
# 10
# 16
# 9
# 12
# 11
# 9
# 8
# 11
# 10
# 13
# 10
# 4
# 11
# 12
# 5
# 12
# 6
# 12
# 14
# 10
# 14
# 13
# 14
# 4
# 12
# 10
